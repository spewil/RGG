# %%
# %matplotlib inline
import numpy as np 
import networkx as nx
import experiment as ex
import network_generation.generation as ng
import matplotlib.pyplot as plt
import pickle
from scipy import stats
from matplotlib.ticker import AutoMinorLocator

# %% [markdown]
# # LCC using networkx

# %%
n, boundary = 100, 'p'
d_range = [2,3,6,9,15,25]
kappa_range = [1,3,5,10,15,20]
num_radii=10

LCCfig = plt.figure()
LCCax = LCCfig.add_subplot(1,1,1)

num_in_LCC = []
num_in_LCC_std = []
md = [] 
md_std = []
ERE = ex.ERExperiment(kappa_range, n)
for ensemble in ERE.ensembles:
    num_in_LCC_sample = []
    md_sample = []
    for sample in ensemble.samples:
        G =  nx.Graph(sample.adjacency_dense) 
        md_sample.append(sample.mean_degree())
        num_in_LCC_sample.append(float(len(sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0]))/n)
    num_in_LCC.append(np.mean(num_in_LCC_sample))
    num_in_LCC_std.append(stats.sem(num_in_LCC_sample))
    md.append(np.mean(md_sample))
    md_std.append(stats.sem(md_sample))
print 'ER done'
LCCax.errorbar(md, num_in_LCC, xerr=md_std, yerr=num_in_LCC_std,label='ER')

for d in d_range:
    num_in_LCC = []
    num_in_LCC_std = []
    md = [] 
    md_std = []
    RGG = ex.RGGExperiment(kappa_range, n, d, shortcut_prob=0, boundary=boundary,num_radii=num_radii)
    for ensemble in RGG.ensembles:
        num_in_LCC_sample = []
        md_sample = []
        for sample in ensemble.samples:
            G =  nx.Graph(sample.adjacency_dense) 
            md_sample.append(sample.mean_degree())
            num_in_LCC_sample.append(float(len(sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0]))/n)
        num_in_LCC.append(np.mean(num_in_LCC_sample))
        num_in_LCC_std.append(stats.sem(num_in_LCC_sample))
        md.append(np.mean(md_sample))
        md_std.append(stats.sem(md_sample))
    print 'd = ' + str(d) + ' done'
    LCCax.errorbar(md, num_in_LCC, xerr=md_std, yerr=num_in_LCC_std,label='d = '+str(d))

legend_handles, legend_strings = LCCax.get_legend_handles_labels()
tenpercent, = LCCax.plot([0,max(kappa_range)],[.9, .9],'--')
legend_handles.append(tenpercent)
legend_strings.append('90%')
LCCax.set_xlabel('Average Mean Degree $\\langle{k}\\rangle$')
LCCax.set_ylabel('Fraction of Nodes in the LCC')
LCCax.legend(legend_handles, legend_strings)

LCCfig.savefig('./plots/num_in_LCC_BC_'+str(boundary)+'_N_'+str(n)+'.eps',dpi=800)
# Out:
# ER done
# d = 2 done
# d = 3 done
# d = 6 done
# d = 9 done
# d = 15 done
# d = 25 done

# %% [markdown]
# # validate homemade code

# %% [markdown]
# # MAXIMAL MATCHINGS NEED NOT BE UNIQUE!!!

# %%
# generate a net 
kappa = 10
n = 100
d = 25

boundary = 's'
num_samples = 100

RGG = ng.RGGEnsemble(kappa, n, d, shortcut_prob=0, boundary=boundary, num_radii=1)
RGG.generate_samples(n=num_samples)
# s.plot_network(unmatched=s.find_unmatched(), LCC=False, save=False)
sizex = []
sizeh = []
for s in RGG.samples:
    G =  nx.Graph(s.adjacency_dense) 
    sizex.append(len(sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0]))
    s.to_LCC()
    sizeh.append(s.LCC_size)
    
print np.mean(sizex)
print np.mean(sizeh)
# Out:
# 99.25
# 99.25

# %%
# import copy

# generate a net 
kappa = 7
n = 300
d = 2
boundary = 'p'
num_samples = 1

RGG = ng.RGGEnsemble(kappa, n, d, shortcut_prob=0, boundary=boundary, num_radii=1)
RGG.generate_samples(n=num_samples)
s = RGG.samples[0]

# G =  nx.Graph(s.adjacency_dense) 
# print len(sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0])

lcc = copy.deepcopy(s)
lcc.to_LCC()

graph = nx.DiGraph(s.adjacency_dense)

posDict = {}
for i in range(len(s.positions)):
    posDict[i] = s.positions[i]     

plt.figure(1)
plt.clf
File_Name = './plots/graphs/RGG_LCC_HI_K_Gray_Periodic.eps'
colorList = []
# make all red to start
for i in range(s.n):
    colorList.append('red')
# make drivers green
for i in s.find_unmatched():
    colorList[i] = 'green'
# make non-LCC grey
for i in range(s.n):
    if i not in lcc.LCC_vec:
        colorList[i] = 'grey'

nx.draw_networkx(graph, pos=posDict, with_labels=False, node_color=colorList, node_size=20, width = 0.5)
plt.savefig( File_Name , format='eps', dpi=1000 )

### NO GREY ###

plt.figure(2)
plt.clf
File_Name = './plots/graphs/RGG_LCC_HI_K_Periodic.eps'
colorList = []
# make all red to start
for i in range(s.n):
    colorList.append('red')
# make drivers green
for i in s.find_unmatched():
    colorList[i] = 'green'

nx.draw_networkx(graph, pos=posDict, with_labels=False, node_color=colorList, node_size=20, width = 0.5)
plt.savefig( File_Name , format='eps', dpi=1000 )

# %% [markdown]
# ## generate data

# %%
# RGG DATA 

import network_generation.generation as ng

kappa_range = [1,3,5,8,10,15,20]
n_range = [50]
d_range = [2,3,6,9,15,25]
boundaries = ['s','p']#['s','p','g']
num_samples = 100

print 'running ' + str(len(n_range)*len(d_range)*len(boundaries)*len(kappa_range)) + ' generations'
i=1

## RGGs ##
for kappa in kappa_range:
    for n in n_range:
        for d in d_range:
            for boundary in boundaries: 
                RGG = ng.RGGEnsemble(kappa, n, d, boundary=boundary, num_radii=10)
                RGG.generate_samples(n=num_samples)
                # data to disk 
                RGG.to_disk()
                print 'saved run ' + str(i)
                i+=1 

# GENERATE ER DATA 
print 'running ' + str(len(n_range)*len(kappa_range)) + ' generations'
i=1
for kappa in kappa_range:
    for n in n_range:
        # make an ER Ensemble
        ER = ng.EREnsemble(kappa,n)
        # generate samples 
        # sample data is stored in the object 
        ER.generate_samples(n=num_samples)
        # data to disk 
        ER.to_disk()
        print 'saved run ' + str(i)
        i+=1

# %% [markdown]
# # LCC using homemade code

# %%
n, boundary = 1000, 's'
d_range = [2,3,6,9,15,25]
kappa_range = [1,3,5,10,15,20]

LCCfig = plt.figure()
LCCax = LCCfig.add_subplot(1,1,1)

### ER ###

frac_in_LCC = []
frac_in_LCC_std = []

ER = ex.ERExperiment(kappa_range, n)

for ensemble in ER.ensembles:
    frac_in_LCC_sample = []
    for sample in ensemble.samples:
        sample.to_LCC()
        # LCC size for each sample 
        frac_in_LCC_sample.append(float(sample.LCC_size)/ER.n)
    # mean over samples of LCC fraction 
    frac_in_LCC.append(np.mean(frac_in_LCC_sample))
    frac_in_LCC_std.append(stats.sem(frac_in_LCC_sample))

mean_degree_list, std_degree_list, _ = ER.find_degree_stats()    

LCCax.errorbar(mean_degree_list, frac_in_LCC, xerr=std_degree_list, yerr=frac_in_LCC_std, label='ER Graph')
print 'ER done'

### RGG ###

for d in d_range:
    frac_in_LCC = []
    frac_in_LCC_std = []

    RGG = ex.RGGExperiment(kappa_range, n, d, shortcut_prob=0, boundary=boundary,num_radii=10)
    
    # find frac stats 
    for ensemble in RGG.ensembles:
        frac_in_LCC_sample = []
        for sample in ensemble.samples:
            sample.to_LCC()
            # LCC size for each sample 
            frac_in_LCC_sample.append(float(sample.LCC_size)/RGG.n)
        # mean over samples of LCC fraction 
        frac_in_LCC.append(np.mean(frac_in_LCC_sample))
        frac_in_LCC_std.append(stats.sem(frac_in_LCC_sample))
    
    # find mean degree stats 
    mean_degree_list, std_degree_list, _ = RGG.find_degree_stats()    
    
    LCCax.errorbar(mean_degree_list, frac_in_LCC, xerr=std_degree_list, yerr=frac_in_LCC_std, label='d = '+str(d))
    print 'd = ' + str(d) + ' done'

legend_handles, legend_strings = LCCax.get_legend_handles_labels()

tenpercent, = LCCax.plot([0,max(kappa_range)],[.9, .9],'-.')
legend_handles.append(tenpercent)
legend_strings.append('90%')
LCCax.set_xlabel('Average Mean Degree $\\langle{k}\\rangle$')
LCCax.set_ylabel('Fraction of Nodes in the LCC')
LCCax.legend(legend_handles, legend_strings)

LCCax.set_xticks(range(0, max(kappa_range)+1, 2))
# minor_locator = AutoMinorLocator(2)
# LCCax.xaxis.set_minor_locator(minor_locator)
# LCCax.yaxis.set_minor_locator(minor_locator)
# LCCax.grid(which='both',alpha=0.2)

LCCfig.savefig('./plots/frac_in_LCC_BC_'+str(boundary)+'_N_'+str(n)+'.eps',dpi=800)
# Out:
# ER done
# d = 2 done
# d = 3 done
# d = 6 done
# d = 9 done
# d = 15 done
# d = 25 done

# %%
print mean_degree_list
print RGG.ensembles[1].num_samples
print RGG.ensembles[1].samples[5].LCC_size
# Out:
# [1.9683107486090194, 3.1265205527543878, 5.1841068939447066, 10.132599999999998, 14.8622, 19.9404]
# 100
# 93

# %% [markdown]
# # visualize some nets
#
# to compare ER and RGG

# %%
# generate a net 
kappa = 5
n = 1000
d = 2
boundary = 's'
num_samples = 1

RGG = ng.RGGEnsemble(kappa, n, d, shortcut_prob=0, boundary=boundary, num_radii=10)
RGG.generate_samples(n=num_samples)
s = RGG.samples[0]
G = nx.DiGraph(s.adjacency_dense)
# print 2*float(nx.number_of_edges(G))/n
# print np.shape(s.adjacency)
s.plot_network(unmatched=s.find_unmatched())
# Out:
# 4.978
# (1000, 1000)

# %%
ER = ng.EREnsemble(kappa, n)
ER.generate_samples(n=num_samples)
p = ER.samples[0]
p.plot_network(unmatched=p.find_unmatched())
# G = nx.DiGraph(p.adjacency_dense)
print 2*float(nx.number_of_edges(G))/n
# nx.draw_random(G,node_size=5,width=0.2)
# Out:
# 2.56

# %% [markdown]
# # hopcroft karp testing

# %%
# generate a net 
kappa = 5
n = 1000
d = 2
boundary = 's'
num_samples = 1

RGG = ng.RGGEnsemble(kappa, n, d, shortcut_prob=0, boundary=boundary, num_radii=1)
RGG.generate_samples(n=num_samples)
s = RGG.samples[0]

# G =  nx.Graph(s.adjacency_dense) 
# print len(sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0])

graph = nx.DiGraph(s.adjacency_dense)

posDict = {}
for i in range(len(s.positions)):
    posDict[i] = s.positions[i]     

plt.figure(1)
plt.clf
File_Name = './plots/graphs/RGG.pdf'
colorList = []
# make all red to start
for i in range(s.n):
    colorList.append('red')
# make drivers green
for i in s.find_unmatched():
    colorList[i] = 'green'

nx.draw_networkx(graph, pos=posDict, with_labels=False, node_color=colorList, node_size=20, width = 0.5)
plt.tight_layout()
plt.ylim([0,1])
plt.xlim([0,1])
plt.savefig( File_Name , format='pdf', dpi=1000 )

# %%
s.bipartite_dict = {0:[1,3],1:[],2:[0,4],3:[1],4:[0,3]}
nx.draw_networkx(nx.DiGraph(s.bipartite_dict))
print s.bipartite_dict
s.bipartite_dict = {'0s':[1,3],'1s':[],'2s':[0,4],'3s':[1],'4s':[0,3]}
s.find_unmatched()
# Out:
# {0: [1, 3], 1: [], 2: [0, 4], 3: [1], 4: [0, 3]}
# [2]

# %%
s.bipartite_dict = {'0s': [0], '1s': [0, 1], '2s': [0, 1], '3s': [1, 2, 3], '4s': [2, 3], '5s': [3, 4, 5],  '6s': [4, 5, 6], '7s': [7]}
print s.find_unmatched()
# Out:
# [6]

# %%
s.bipartite_dict = {'0s': [2,1], '1s': [], '2s': []}#, '3s': [1, 2, 3], '4s': [2, 3], '5s': [3, 4, 5],  '6s': [4, 5, 6], '7s': [7]}
print s.find_unmatched()
# Out:
# [0, 2]

# %%
s.bipartite_dict = {'0s': [1], '1s': [2,3], '2s': [], '3s': [4,9], '4s': [2,5,14], '5s': [6],  '6s': [7], '7s': [8], '8s':[5],'9s':[10],'10s':[11],'11s':[12],'12s':[13],'13s':[9],'14s':[15,16],'15s':[19,20],'16s':[17],'17s':[18],'18s':[16],'19s':[],'20s':[21],'21s':[]}
print s.find_unmatched()
# Out:
# [0, 3, 20]

# %%
s.bipartite_dict = {'1s': [2,3], '2s': [4], '3s': [4], '4s': [5,14], '5s': [6],  '6s': [7], '7s': [8], '8s':[5],'9s':[3,10],'10s':[11],'11s':[12],'12s':[13],'13s':[9],'14s':[15,16],'15s':[19,20],'16s':[17],'17s':[18],'18s':[16],'19s':[],'20s':[21],'21s':[]}
print s.find_unmatched()
#make adjacency 
n = len(s.bipartite_dict.keys())
A = np.zeros([n,n])
for key in s.bipartite_dict.keys():
    for t in s.bipartite_dict[key]:
        A[int(key[:-1])][t] = 1
G = nx.DiGraph(A)
nx.draw_networkx(G,layout='order')
# Out:
# [0, 1, 10, 14, 20]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-153-93c3c3f1b0b1> in <module>()
#       6 for key in s.bipartite_dict.keys():
#       7     for t in s.bipartite_dict[key]:
# ----> 8         A[int(key[:-1])][t] = 1
#       9 G = nx.DiGraph(A)
#      10 nx.draw_networkx(G,layout='order')
#
# IndexError: index 21 is out of bounds for axis 0 with size 21

# %%
# generate a net 
kappa = 8
n = 20
d = 2
boundary = 's'
num_samples = 1

RGG = ng.RGGEnsemble(kappa, n, d, shortcut_prob=0, boundary=boundary, num_radii=1)
RGG.generate_samples(n=num_samples)
s = RGG.samples[0]

s.plot_network(unmatched=s.find_unmatched())
